# %%
No_of_Eq = int(input("Enter Number of equation you have : "))

equations = []

for _ in range(1,No_of_Eq+1):
    equations.append(input(f"Enter {_} Equation : "))

# %%
equations
# Out:
# ['3x+2y-3z=8']

# %%
term = equations[0].replace('+',' ').replace('-',' ').replace('=',' ')

# %%
term.split()
# Out:
# ['3x', '2y', '3z', '8']

# %%
for _ in term:
